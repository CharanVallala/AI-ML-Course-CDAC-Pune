# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img = plt.imread('images/lenna.png')

# %%
img.shape
# Out:
# (512, 512, 3)

# %% [markdown]
# Crop into given dimensions

# %%
img2 = img[150:300,200:350]

# %%
plt.imshow(img)

# %%
plt.imshow(img2)

# %% [markdown]
# Crop 15% from all borders

# %%
img3 = img[77:435,77:435]
plt.imshow(img3)

# %%
height,width,channels = img.shape

# %%
startRow = int(height*.15)
startCol = int(width*.15)
endRow   = int(height*.85)
endCol   = int(width*.85)

# %%
img4 = img[startRow:endRow,startCol:endCol]
plt.imshow(img4)

# %%
x =  np.array([[5,6,7],[1,2,3],[8,0,9]])
y =  np.array([[3,4,5],[4,5,6],[7,8,9]])

# %%
x, y
# Out:
# (array([[5, 6, 7],
#         [1, 2, 3],
#         [8, 0, 9]]),
#  array([[3, 4, 5],
#         [4, 5, 6],
#         [7, 8, 9]]))

# %%
x_y = np.hstack([x,y])
x_y
# Out:
# array([[5, 6, 7, 3, 4, 5],
#        [1, 2, 3, 4, 5, 6],
#        [8, 0, 9, 7, 8, 9]])

# %%
xy = np.vstack([x,y])
xy
# Out:
# array([[5, 6, 7],
#        [1, 2, 3],
#        [8, 0, 9],
#        [3, 4, 5],
#        [4, 5, 6],
#        [7, 8, 9]])

# %%
image = cv2.imread('images/lenna.png')
img_flip_hor = cv2.flip(image, 0)

# %%
new_image = np.hstack([image,img_flip_hor])

plt.imshow(new_image)
