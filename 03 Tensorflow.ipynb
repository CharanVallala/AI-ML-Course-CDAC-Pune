# %%
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import tensorflow as tf
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
pip install tensorflow -U
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/46.2 kB ? eta -:--:--
#      ---------------------------------------- 46.2/46.2 kB 2.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/377.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/377.0 MB 5.2 MB/s eta 0:01:13
#    ---------------------------------------- 0.5/377.0 MB 8.3 MB/s eta 0:00:46
#    ---------------------------------------- 1.0/377.0 MB 8.6 MB/s eta 0:00:44
#    ---------------------------------------- 2.4/377.0 MB 17.0 MB/s eta 0:00:23
#     --------------------------------------- 4.8/377.0 MB 25.3 MB/s eta 0:00:15
#     --------------------------------------- 7.9/377.0 MB 36.1 MB/s eta 0:00:11
#    - -------------------------------------- 11.3/377.0 MB 73.1 MB/s eta 0:00:06
# ...

# %%
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import tensorflow as tf
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
import tensorflow as tf

# %%
tf
# Out:
# <module 'tensorflow' from 'C:\\Users\\rajesh\\AppData\\Roaming\\Python\\Python311\\site-packages\\tensorflow\\__init__.py'>

# %%
#create tensors
a = tf.constant([1,2,3])
b = tf.constant([4,5,6])

# %%
print('tensor a:',a)
print('tensor b:',b)
# Out:
# tensor a: tf.Tensor([1 2 3], shape=(3,), dtype=int32)
# tensor b: tf.Tensor([4 5 6], shape=(3,), dtype=int32)

# %%
a[0]
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=1>

# %%
x = tf.constant([[1,2,3],[7,8,9]])
y = tf.constant([[4,5,6],[1,2,3]])

# %%
x
# Out:
# <tf.Tensor: shape=(2, 3), dtype=int32, numpy=
# array([[1, 2, 3],
#        [7, 8, 9]])>

# %%
x = tf.constant([[[1,2,3],[7,8,9]],[[3,4,5],[5,6,7]]])

# %%
x
# Out:
# <tf.Tensor: shape=(2, 2, 3), dtype=int32, numpy=
# array([[[1, 2, 3],
#         [7, 8, 9]],
#
#        [[3, 4, 5],
#         [5, 6, 7]]])>

# %%
#Add tensors
c = a+b

# %%
c
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([5, 7, 9])>

# %%
c.numpy()
# Out:
# array([5, 7, 9])

# %%
a//b
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([0, 0, 0])>

# %%
b//a #floor division
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([4, 2, 2])>

# %%
b/a #float division
# Out:
# <tf.Tensor: shape=(3,), dtype=float64, numpy=array([4. , 2.5, 2. ])>

# %%
import numpy as np

# %%
#Matrix multiplication
a_mx = tf.constant([[2,3],[4,5]],dtype=np.int32)
b_mx = tf.constant([[2,3],[4,5]].dtype=np.int8)
c = tf.matmul(a_mx,b_mx)
print(c)
# Out:
#   Cell In[34], line 3
#     b_mx = tf.constant([[2,3],[4,5]].dtype=np.int8)
#                        ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?
