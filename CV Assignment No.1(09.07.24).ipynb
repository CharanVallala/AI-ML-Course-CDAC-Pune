# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
import os
os.getcwd()
# Out:
# 'd:\\AI & ML CDAC PUNE\\AI-Course-Pune'

# %% [markdown]
# 1 Load image

# %%
img = cv2.imread('images/sachin.jpg')

# %% [markdown]
# 1.1 Size and shape of image

# %%
img.size,img.shape
# Out:
# (2741250, (1075, 850, 3))

# %% [markdown]
# 1.3 Display using OpenCV, matplotlib

# %%
cv2.imshow('sachin',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img_rgb=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %% [markdown]
# 1.2 Color Space model

# %%
img2 = cv2.imread('images/sachin.jpg',0)
plt.figure(figsize=(16,9))
plt.subplot(2,4,1)
plt.title('PiYG')
plt.imshow(img2, cmap = 'PiYG')
plt.subplot(2,4,2)
plt.title('PRGn')
plt.imshow(img2, cmap = 'PRGn')
plt.subplot(2,4,3)
plt.title('BrBG')
plt.imshow(img2, cmap = 'BrBG')
plt.subplot(2,4,4)
plt.title('PuOr')
plt.imshow(img2, cmap = 'PuOr')
plt.subplot(2,4,5)
plt.title('RdGy')
plt.imshow(img2, cmap = 'RdGy')
plt.subplot(2,4,6)
plt.title('RdBu')
plt.imshow(img2, cmap = 'RdBu')
plt.subplot(2,4,7)
plt.title('RdYlBu')
plt.imshow(img2, cmap = 'RdYlBu')
plt.subplot(2,4,8)
plt.title('Spectral')
plt.imshow(img2, cmap = 'Spectral')

# %% [markdown]
# 2. 5x5 image using Color maps

# %%
img2 = cv2.imread('images/sachin.jpg',0)
plt.figure(figsize=(16,9))
plt.subplot(2,4,1)
plt.title('gray')
plt.imshow(img2, cmap = 'gray')
plt.subplot(2,4,2)
plt.title('2.1.coolwarm')
plt.imshow(img2, cmap = 'coolwarm')
plt.subplot(2,4,3)
plt.title('2.2.rainbow')
plt.imshow(img2, cmap = 'rainbow')
plt.subplot(2,4,4)
plt.title('2.3.tab10')
plt.imshow(img2, cmap = 'tab10')
plt.subplot(2,4,5)
plt.title('2.4.seismic')
plt.imshow(img2, cmap = 'seismic')
plt.subplot(2,4,6)
plt.title('2.5.twilight')
plt.imshow(img2, cmap = 'twilight')
plt.subplot(2,4,7)
plt.title('2.6.turbo')
plt.imshow(img2, cmap = 'turbo')
plt.subplot(2,4,8)
plt.title('2.7.BuGn')
plt.imshow(img2, cmap = 'BuGn')

# %% [markdown]
# 3. White Pixels

# %%
img3 = cv2.imread('images/sachin.jpg')
for i in range (100,200) :
    for j in range (150,350) :
        img3[i,j] = 255
cv2.imshow('white',img3)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# 4.Video Operations

# %%
vid = cv2.VideoCapture('images/nature.mp4')
vid
# Out:
# < cv2.VideoCapture 0000023310AA5630>

# %%
retrieve, frame = vid.read()
retrieve
# Out:
# True

# %%
frame.size, frame.shape
# Out:
# (2743200, (720, 1270, 3))

# %%
width = int(vid.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(vid.get(cv2.CAP_PROP_FRAME_HEIGHT))
frames = int(vid.get(cv2.CAP_PROP_FRAME_COUNT))
fps = int(vid.get(cv2.CAP_PROP_FPS))
print('Height',height)
print('Width',width)
print('Total frames ', frames)
print('FPS',fps)
# Out:
# Height 720
# Width 1270
# Total frames  1409
# FPS 26

# %%
vid = cv2.VideoCapture('images/nature.mp4')
while True:
    retrieve, frame =  vid.read()
    if not retrieve:
        break
    cv2.imshow('Video',frame)
    if cv2.waitKey(0) == ord('q'): #press q to exit video
        break
cv2.destroyAllWindows()

# %%
timestamp = '00:00:50.00'
hours, minutes, seconds =[float(i) for i in timestamp.split(':')]
fps = 26
trigger_frame = hours*3600*fps + minutes * 60 * fps + seconds * fps
vid.set(1, trigger_frame)
success, frame = vid.read()
if success:
    cv2.imwrite('frame_50s.jpg',frame)
